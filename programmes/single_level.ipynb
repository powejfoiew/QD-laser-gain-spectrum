# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('qd_single_pop.csv')
current = df['        Xvals']
pop = df['      Yvals1 ']
idx=100
plt.plot(current[idx:],pop[idx:])
plt.xlabel('Time [ns]')
plt.ylabel('Carrier density [cm^-3]')
plt.show()
